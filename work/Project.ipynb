# %%
import pandas as pd

# %%
df = pd.read_csv("../data/offenses-standardized.csv")
# Out:
# /tmp/ipykernel_2503315/1690201376.py:1: DtypeWarning: Columns (4,7,10,14,15,16,17,18,19,20,21,22,24,25,27,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/offenses-standardized.csv")

# %%
df
# Out:
#                           row_hash           source    agency_name agency_ori  \
# 0       MDBPD0000-C419771020-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 1       MDBPD0000-B63BECA76C-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 2       MDBPD0000-8A7079014F-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 3       MDBPD0000-3EF6B5EBEF-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 4       MDBPD0000-5995BFA411-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# ...                            ...              ...            ...        ...
# 747653  DE0020600-FA3E31C6F4-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 747654  DE0020600-3B63C6B8FA-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 747655  DE0020600-5E6B6C33DC-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 747656  DE0020600-FE85CDD7D2-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 747657  DE0020600-DC272A16C4-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
#
# ...

# %%
df.columns
# Out:
# Index(['row_hash', 'source', 'agency_name', 'agency_ori', 'agency_incident_id',
#        'occurred_date', 'occurred_time', 'offense_category',
#        'top_ucr_classification', 'top_local_classification', 'nibrs_code',
#        'weapon', 'firearm_ind', 'offense_group', 'domestic_violence_ind',
#        'family_violence_ind', 'gang_activity_ind', 'relationship_to_offender',
#        'circumstance', 'inside_outside', 'victim_age', 'victim_race',
#        'victim_ethnicity', 'victim_race_condensed', 'victim_sex',
#        'case_status', 'arrest_ind', 'clearance_status', 'clearance_group',
#        'clearance_date', 'arrest_date'],
#       dtype='object')

# %%
df[['agency_name','offense_category']]
# Out:
#           agency_name    offense_category
# 0        BALTIMORE-PD  NON FATAL SHOOTING
# 1        BALTIMORE-PD  NON FATAL SHOOTING
# 2        BALTIMORE-PD  NON FATAL SHOOTING
# 3        BALTIMORE-PD  NON FATAL SHOOTING
# 4        BALTIMORE-PD  NON FATAL SHOOTING
# ...               ...                 ...
# 747653  WILMINGTON-PD  AGGRAVATED ASSAULT
# 747654  WILMINGTON-PD  AGGRAVATED ASSAULT
# 747655  WILMINGTON-PD  AGGRAVATED ASSAULT
# 747656  WILMINGTON-PD  AGGRAVATED ASSAULT
# 747657  WILMINGTON-PD  AGGRAVATED ASSAULT
#
# [747658 rows x 2 columns]

# %%
df['agency_name'].value_counts()
# Out:
# CHICAGO-PD             277260
# PHILADELPHIA-PD        104732
# LOS-ANGELES-PD          95997
# HOUSTON-PD              54371
# TUCSON-PD               47492
# SAN-DIEGO-PD            39586
# ST-LOUIS-MPD            29703
# LOUISVILLE-MPD          26367
# PITTSBURGH-PD           16352
# LAS-VEGAS-MPD           13667
# DALLAS-PD               10489
# COLORADO-SPRINGS-PD      7700
# CINCINNATI-PD            6484
# BALTIMORE-PD             5143
# WILMINGTON-PD            3770
# NEWARK-PD                2568
# NEW-ORLEANS-PD           2166
# SAN-FRANCISCO-PD         1758
# BOSTON-PD                 881
# NEW-YORK-CITY-PD          624
# DENVER-PD                 360
# ORLANDO-PD                188
# Name: agency_name, dtype: int64

# %%
df = pd.read_csv("../work/Total Crimes.csv")

# %%
df
# Out:
#             Location  Total Crimes
# 0            Chicago        277260
# 1       Philadelphia        104732
# 2        Los Angeles         95997
# 3            Houston         54371
# 4             Tucson         47492
# 5          San Diego         39586
# 6           St Louis         29703
# 7         Louisville         26367
# 8         Pittsburgh         16352
# 9          Las Vegas         13667
# 10            Dallas         10489
# 11  Colorado Springs          7700
# 12        Cincinnati          6484
# 13         Baltimore          5143
# 14        Wilmington          3770
# 15            Newark          2568
# 16       New Orleans          2166
# 17     San Francisco          1758
# 18            Boston           881
# 19     New York City           624
# 20            Denver           360
# 21           Orlando           188

# %%
import matplotlib as plt

# %%
data = pd.read_csv('../work/Total Crimes.csv')

# %%
data.plot(figsize=(10,10));

# %%
data.plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
data.plot.bar(x='Location', y='Total Crimes',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
df = pd.read_csv("../work/homicide.csv")

# %%
df
# Out:
#                          row_hash           source    agency_name agency_ori  \
# 0      MDBPD0000-D5C9ED4F2D-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 1      MDBPD0000-0388D86539-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 2      MDBPD0000-0F8D5BB8ED-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 3      MDBPD0000-B013F11046-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# 4      MDBPD0000-E6DF1A31ED-01-01   BALTIMORE-MAIN   BALTIMORE-PD  MDBPD0000
# ...                           ...              ...            ...        ...
# 32754  DE0020600-51BD3ADDC1-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 32755  DE0020600-49D47B6C29-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 32756  DE0020600-CE1FC907B1-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 32757  DE0020600-436BE33333-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
# 32758  DE0020600-76759B5402-01-01  WILMINGTON-MAIN  WILMINGTON-PD  DE0020600
#
# ...

# %%
df.columns
# Out:
# Index(['row_hash', 'source', 'agency_name', 'agency_ori', 'agency_incident_id',
#        'occurred_date', 'occurred_time', 'offense_category',
#        'top_ucr_classification', 'top_local_classification', 'nibrs_code',
#        'weapon', 'firearm_ind', 'offense_group', 'domestic_violence_ind',
#        'family_violence_ind', 'gang_activity_ind', 'relationship_to_offender',
#        'circumstance', 'inside_outside', 'victim_age', 'victim_race',
#        'victim_ethnicity', 'victim_race_condensed', 'victim_sex',
#        'case_status', 'arrest_ind', 'clearance_status', 'clearance_group',
#        'clearance_date', 'arrest_date'],
#       dtype='object')

# %%
df['agency_name'].value_counts()
# Out:
# CHICAGO-PD             8504
# HOUSTON-PD             3804
# PHILADELPHIA-PD        3788
# LOS-ANGELES-PD         2343
# ST-LOUIS-MPD           1800
# DALLAS-PD              1783
# BALTIMORE-PD           1522
# TUCSON-PD              1450
# NEWARK-PD              1154
# LOUISVILLE-MPD          858
# SAN-FRANCISCO-PD        850
# LAS-VEGAS-MPD           849
# PITTSBURGH-PD           726
# BOSTON-PD               706
# CINCINNATI-PD           697
# NEW-YORK-CITY-PD        624
# SAN-DIEGO-PD            487
# DENVER-PD               360
# ORLANDO-PD              188
# COLORADO-SPRINGS-PD     138
# WILMINGTON-PD           128
# Name: agency_name, dtype: int64

# %%
df = pd.read_csv("../work/total-homicides.csv")

# %%
df
# Out:
#             Location  Total Homicides
# 0            Chicago             8504
# 1       Philadelphia             3788
# 2        Los Angeles             2343
# 3            Houston             3808
# 4             Tucson             1450
# 5          San Diego              487
# 6           St Louis             1800
# 7         Louisville              858
# 8         Pittsburgh              727
# 9          Las Vegas              849
# 10            Dallas             1783
# 11  Colorado Springs              138
# 12        Cincinnati              697
# 13         Baltimore             1522
# 14        Wilmington              128
# 15            Newark             1154
# 16     San Francisco              850
# 17            Boston              706
# 18     New York City              624
# 19            Denver              360
# 20           Orlando              188

# %%
data = pd.read_csv('../work/total-homicides.csv')

# %%
data.plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
data.plot.bar(x='Location', y='Total Homicides',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Location'>
