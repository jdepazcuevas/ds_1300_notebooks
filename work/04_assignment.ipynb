# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
data = pd.read_csv('../data/nba_18_19_pg.csv')

# %%
data.head()
# Out:
#    Rk                  Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1  Álex Abrines\abrinal01  SG   25  OKC  31   2  19.0  1.8   5.1  ...
# 1   2      Quincy Acy\acyqu01  PF   28  PHO  10   0  12.3  0.4   1.8  ...
# 2   3  Jaylen Adams\adamsja01  PG   22  ATL  34   1  12.6  1.1   3.2  ...
# 3   4  Steven Adams\adamsst01   C   25  OKC  80  80  33.4  6.0  10.1  ...
# 4   5   Bam Adebayo\adebaba01   C   21  MIA  82  28  23.3  3.4   5.9  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.923  0.2  1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  0.700  0.3  2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  0.778  0.3  1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  0.500  4.9  4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  0.735  2.0  5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
ax = data.plot.scatter(x='Tm', y='PTS', color='Red',label="Points by Team")
data.plot.scatter(x='TM', y='PTS', color='g', label="Rookies 2019", ax=ax,figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lustre/work/client/users/jdepazcuevas/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /lustre/work/client/users/jdepazcuevas/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /lustre/work/client/users/jdepazcuevas/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
X=data['Tm'].values
Y=data['PTS'].values

# %%
def lin_reg(x,y):
    # Calculate the average x and y
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)): # This represents our sums
        num = num + (x[i] - x_avg)*(y[i] - y_avg) # Our numerator
        den = den + (x[i] - x_avg)**2 # Our denominator
    # Calculate slope
    m = num / den
    # Calculate intercept
    b = y_avg - m*x_avg

    print (m, b)
    
    # Calculate our predicted y values
    y_pred = m*x + b
    
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 Y_pred = lin_reg(X,Y)
#
# Input In [14], in lin_reg(x, y)
#       1 def lin_reg(x,y):
#       2     # Calculate the average x and y
# ----> 3     x_avg = np.mean(x)
#       4     y_avg = np.mean(y)
#       6     num = 0
#
# NameError: name 'np' is not defined

# %%
# My plot shows the overall production of the rookie NBA class of 2019, the scatterplot was effective in showing the highest concentration of production while avoiding the high and low outliers.
